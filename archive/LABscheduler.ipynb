# %%
import pandas as pd
from fuzzywuzzy import fuzz, process

# %%
class Physician:
    def __init__(self, name, speciality, location, monAM, monPM, tueAM, tuePM, wedAM, wedPM, thuAM, thuPM):
        self.name = name
        self.speciality = speciality
        self.availability = {
            'monAM': monAM,
            'monPM': monPM,
            'tueAM': tueAM,
            'tuePM': tuePM,
            'wedAM': wedAM,
            'wedPM': wedPM,
            'thuAM': thuAM,
            'thuPM': thuPM
        }
        self.location = location

    def update_availability(self, time_slot):
        self.availability[time_slot] = False

    def __str__(self):
        return f"Name: {self.name}\nSpeciality: {self.speciality}\nAvailability: {self.availability}"

class Student:
    def __init__(self, name, flex_time, location, preference):
        self.name = name
        self.assignment = {
            "monAM": None,
            "monPM": None,
            "tueAM": None,
            "tuePM": None,
            "wedAM": None,
            "wedPM": None,
            "thuAM": None,
            "thuPM": None
        }
        self.assignment[flex_time] = "FLEX"
        self.specialities_assigned = {
            "FM": 2,
            "IM": 1,
            "Peds": 1,
            #"PalMed": 1,
            "Geriatrics": 1
        }
        self.location = location
        self.preference = preference

    def update_assignment(self, time_slot, physician):
        self.assignment[time_slot] = physician

    def __str__(self):
        return f"Name: {self.name}\nAssignment: {self.assignment}\nSpecialities Assigned: {self.specialities_assigned}"

# %%
def create_students(students_df):
    """
    Creates a list of Student objects from a 2-column dataframe of student names and their preferred flex time.
    """
    students = []

    for _, row in students_df.iterrows():
        student = Student(row['name'], row['flex_time'], row['location'], row['preference'])
        students.append(student)
    
    return students

def create_physicians(physicians_df):
    """
    Creates a list of Physician objects from a dataframe of physicians with the associated speciality and their availability.
    """
    physicians = {}

    for _, row in physicians_df.iterrows():
        physician = Physician(
            row['name'],
            row['speciality'],
            row['location'],
            row['monAM'],
            row['monPM'],
            row['tueAM'],
            row['tuePM'],
            row['wedAM'],
            row['wedPM'],
            row['thuAM'],
            row['thuPM']
        )
        physicians[row['name']] = physician

    return physicians

def find_time(student, physician):
    for time_slot in student.assignment:
        if (student.assignment[time_slot] == None) and (physician.availability[time_slot]):
            return time_slot
    return None

def generate_student_schedule(students):
    """
    Generates a human-readable dataframe where each row represents a student. The assignment on each session is given in the column with the physicians name and speciality
    """
    # Create an empty DataFrame to store the schedule
    schedule_df = pd.DataFrame(columns=["Student", "monAM", "monPM", "tueAM", "tuePM", "wedAM", "wedPM", "thuAM", "thuPM"])

    # Iterate through each student
    for student in students:
        schedule = {
            "Student": student.name,
            "monAM": "FLEX" if student.assignment["monAM"] == "FLEX" else "free time",
            "monPM": "FLEX" if student.assignment["monPM"] == "FLEX" else "free time",
            "tueAM": "FLEX" if student.assignment["tueAM"] == "FLEX" else "free time",
            "tuePM": "FLEX" if student.assignment["tuePM"] == "FLEX" else "free time",
            "wedAM": "FLEX" if student.assignment["wedAM"] == "FLEX" else "free time",
            "wedPM": "FLEX" if student.assignment["wedPM"] == "FLEX" else "free time",
            "thuAM": "FLEX" if student.assignment["thuAM"] == "FLEX" else "free time",
            "thuPM": "FLEX" if student.assignment["thuPM"] == "FLEX" else "free time"
        }

        # Iterate through the assignments to fill in the physician names
        for time_slot, physician in student.assignment.items():
            if physician != "FLEX" and physician != None:
                schedule[time_slot] = physician.name + " (" + physician.speciality + ", " + physician.location + ")"

        # Append the schedule for the current student to the DataFrame
        schedule_df.loc[len(schedule_df)] = schedule
        #schedule_df = schedule_df.append(schedule, ignore_index=True)

    return schedule_df

# %%
students_df = pd.read_csv("./input/students.csv")
physicians_df = pd.read_csv("./input/physicians.csv")

students = create_students(students_df)
physicians = create_physicians(physicians_df)
physicians_list = physicians_df['name']

for student in students:
    for specialty in student.specialities_assigned:
        while student.specialities_assigned[specialty] > 0:
            try:
                physician = physicians[process.extractOne(student.preference, physicians_list)[0]]
                time_slot = find_time(student, physician)
                if (time_slot != None) and (physician.speciality == specialty):
                    student.update_assignment(time_slot, physician)
                    physician.update_availability(time_slot)
                    student.specialities_assigned[specialty] -= 1
                    break
                else:
                    raise Exception()
            except:
                for name, physician in physicians.items():
                    if physician.speciality == specialty:
                        time_slot = find_time(student, physician)
                        if time_slot != None:
                            student.update_assignment(time_slot, physician)
                            physician.update_availability(time_slot)
                            student.specialities_assigned[specialty] -= 1
                            break

schedule_df = generate_student_schedule(students)
schedule_df
# Out:
#       Student                                              monAM  \
# 0    student1  Dobler, Kim/Marsh, Lisa/Goettemoeller, Michell...
# 1    student2                 Tchelidze, Tea (IM, Beachwood FHC)
# 2    student3             Preston, Andrea (Peds, Avon Point FHC)
# 3    student4                                               FLEX
# 4    student5                                               FLEX
# 5    student6  Alfes, John/Komitau, Jason/Hollingsworth, Ambe...
# 6    student7            Van Keuls, Nancy (Peds, Avon Point FHC)
# 7    student8  Chisholm, Jessica/Cloud, Lisa/Anderson, Elizab...
# 8    student9  Tousi, Babak (Geriatrics, Lakewood Medical Bui...
# 9   student10  Yepes-Rios, Monica (IM, Lutheran Hospital Medi...
# 10  student11        Hashmi, Ardeshir (Geriatrics, Lakewood FHC)
# 11  student12                                          free time
# 12  student13  Allan, Daniel/Krajcik, Daniel/Waite, Coulton (...
# 13  student14                                          free time
# 14  student15                Hazen, Jaclyn (Peds, Beachwood FHC)
# 15  student16  Boose, Eric/Shah, Hardeepak (FM, Brecksville  ...
# 16  student17             Reddy, Sathya (Geriatrics, Lorain FHC)
#
#                                                 monPM  \
# 0   Dobler, Kim/Marsh, Lisa/Goettemoeller, Michell...
# 1              Preston, Andrea (Peds, Avon Point FHC)
# 2                  Tchelidze, Tea (IM, Beachwood FHC)
# 3   Tousi, Babak (Geriatrics, Lakewood Medical Bui...
# 4   Alfes, John/Komitau, Jason/Hollingsworth, Ambe...
# 5                                           free time
# 6         Hashmi, Ardeshir (Geriatrics, Lakewood FHC)
# 7   Yepes-Rios, Monica (IM, Lutheran Hospital Medi...
# 8   Chisholm, Jessica/Cloud, Lisa/Anderson, Elizab...
# 9                                           free time
# 10                                          free time
# 11            Van Keuls, Nancy (Peds, Avon Point FHC)
# 12                                               FLEX
# 13  Allan, Daniel/Krajcik, Daniel/Waite, Coulton (...
# 14             Reddy, Sathya (Geriatrics, Lorain FHC)
# 15                 Ayala, Sudha (IM, Main Campus/G10)
# 16  Boose, Eric/Shah, Hardeepak (FM, Brecksville  ...
#
#                                                 tueAM  \
# 0                  Tchelidze, Tea (IM, Beachwood FHC)
# 1   Dobler, Kim/Marsh, Lisa/Goettemoeller, Michell...
# 2                                                FLEX
# 3              Preston, Andrea (Peds, Avon Point FHC)
# 4   Alfes, John/Komitau, Jason/Hollingsworth, Ambe...
# 5   Tousi, Babak (Geriatrics, Lakewood Medical Bui...
# 6                                           free time
# 7             Van Keuls, Nancy (Peds, Avon Point FHC)
# 8                                           free time
# 9   Chisholm, Jessica/Cloud, Lisa/Anderson, Elizab...
# 10  Yepes-Rios, Monica (IM, Lutheran Hospital Medi...
# 11                                               FLEX
# 12  Allan, Daniel/Krajcik, Daniel/Waite, Coulton (...
# 13        Hashmi, Ardeshir (Geriatrics, Lakewood FHC)
# 14                                          free time
# 15                                          free time
# 16                Hazen, Jaclyn (Peds, Beachwood FHC)
#
#                                                 tuePM  \
# 0              Preston, Andrea (Peds, Avon Point FHC)
# 1   Dobler, Kim/Marsh, Lisa/Goettemoeller, Michell...
# 2   Tousi, Babak (Geriatrics, Lakewood Medical Bui...
# 3                  Tchelidze, Tea (IM, Beachwood FHC)
# 4                                           free time
# 5   Alfes, John/Komitau, Jason/Hollingsworth, Ambe...
# 6                                           free time
# 7         Hashmi, Ardeshir (Geriatrics, Lakewood FHC)
# 8             Van Keuls, Nancy (Peds, Avon Point FHC)
# 9                                                FLEX
# 10  Chisholm, Jessica/Cloud, Lisa/Anderson, Elizab...
# 11  Yepes-Rios, Monica (IM, Lutheran Hospital Medi...
# 12                                          free time
# 13  Allan, Daniel/Krajcik, Daniel/Waite, Coulton (...
# 14                                          free time
# 15                                          free time
# 16                                               FLEX
#
#                                                 wedAM  \
# 0   Tousi, Babak (Geriatrics, Lakewood Medical Bui...
# 1                                           free time
# 2   Dobler, Kim/Marsh, Lisa/Goettemoeller, Michell...
# 3                                           free time
# 4                  Tchelidze, Tea (IM, Beachwood FHC)
# 5              Preston, Andrea (Peds, Avon Point FHC)
# 6   Alfes, John/Komitau, Jason/Hollingsworth, Ambe...
# 7                                           free time
# 8                                                FLEX
# 9   Chisholm, Jessica/Cloud, Lisa/Anderson, Elizab...
# 10                                               FLEX
# 11        Hashmi, Ardeshir (Geriatrics, Lakewood FHC)
# 12  Yepes-Rios, Monica (IM, Lutheran Hospital Medi...
# 13                                               FLEX
# 14  Allan, Daniel/Krajcik, Daniel/Waite, Coulton (...
# 15            Van Keuls, Nancy (Peds, Avon Point FHC)
# 16                                          free time
#
#                                                 wedPM  \
# 0                                           free time
# 1   Tousi, Babak (Geriatrics, Lakewood Medical Bui...
# 2   Dobler, Kim/Marsh, Lisa/Goettemoeller, Michell...
# 3                                           free time
# 4              Preston, Andrea (Peds, Avon Point FHC)
# 5                  Tchelidze, Tea (IM, Beachwood FHC)
# 6   Alfes, John/Komitau, Jason/Hollingsworth, Ambe...
# 7                                           free time
# 8                                           free time
# 9                                           free time
# 10  Chisholm, Jessica/Cloud, Lisa/Anderson, Elizab...
# 11                                          free time
# 12            Van Keuls, Nancy (Peds, Avon Point FHC)
# 13  Yepes-Rios, Monica (IM, Lutheran Hospital Medi...
# 14  Allan, Daniel/Krajcik, Daniel/Waite, Coulton (...
# 15        Hashmi, Ardeshir (Geriatrics, Lakewood FHC)
# 16                                          free time
#
#                                                 thuAM  \
# 0                                           free time
# 1                                           free time
# 2                                           free time
# 3   Dobler, Kim/Marsh, Lisa/Goettemoeller, Michell...
# 4   Tousi, Babak (Geriatrics, Lakewood Medical Bui...
# 5                                           free time
# 6                  Tchelidze, Tea (IM, Beachwood FHC)
# 7                                                FLEX
# 8   Alfes, John/Komitau, Jason/Hollingsworth, Ambe...
# 9              Preston, Andrea (Peds, Avon Point FHC)
# 10                                          free time
# 11  Chisholm, Jessica/Cloud, Lisa/Anderson, Elizab...
# 12        Hashmi, Ardeshir (Geriatrics, Lakewood FHC)
# 13            Van Keuls, Nancy (Peds, Avon Point FHC)
# 14  Yepes-Rios, Monica (IM, Lutheran Hospital Medi...
# 15                                               FLEX
# 16  Allan, Daniel/Krajcik, Daniel/Waite, Coulton (...
#
#                                                 thuPM
# 0                                                FLEX
# 1                                                FLEX
# 2                                           free time
# 3   Dobler, Kim/Marsh, Lisa/Goettemoeller, Michell...
# 4                                           free time
# 5                                                FLEX
# 6                                                FLEX
# 7   Alfes, John/Komitau, Jason/Hollingsworth, Ambe...
# 8                  Tchelidze, Tea (IM, Beachwood FHC)
# 9   Tousi, Babak (Geriatrics, Lakewood Medical Bui...
# 10             Preston, Andrea (Peds, Avon Point FHC)
# 11  Chisholm, Jessica/Cloud, Lisa/Anderson, Elizab...
# 12                                          free time
# 13                                          free time
# 14                                               FLEX
# 15  Allan, Daniel/Krajcik, Daniel/Waite, Coulton (...
# 16  Yepes-Rios, Monica (IM, Lutheran Hospital Medi...
