# %%
import pandas as pd

# %%
class Physician:
    def __init__(self, name, speciality, location, monAM, monPM, tueAM, tuePM, wedAM, wedPM, thuAM, thuPM):
        self.name = name
        self.speciality = speciality
        self.availability = {
            'monAM': monAM,
            'monPM': monPM,
            'tueAM': tueAM,
            'tuePM': tuePM,
            'wedAM': wedAM,
            'wedPM': wedPM,
            'thuAM': thuAM,
            'thuPM': thuPM
        }
        self.location = location

    def update_availability(self, time_slot):
        self.availability[time_slot] = False

    def __str__(self):
        return f"Name: {self.name}\nSpeciality: {self.speciality}\nAvailability: {self.availability}"

class Student:
    def __init__(self, name, flex_time, location):
        self.name = name
        self.assignment = {
            "monAM": None,
            "monPM": None,
            "tueAM": None,
            "tuePM": None,
            "wedAM": None,
            "wedPM": None,
            "thuAM": None,
            "thuPM": None
        }
        self.assignment[flex_time] = "FLEX"
        self.specialities_assigned = {
            "FM": 2,
            "IM": 1,
            "Peds": 1,
            #"PalMed": 1,
            "Geriatrics": 1
        }
        self.location = location

    def update_assignment(self, time_slot, physician):
        self.assignment[time_slot] = physician

    def __str__(self):
        return f"Name: {self.name}\nAssignment: {self.assignment}\nSpecialities Assigned: {self.specialities_assigned}"

# %%
def create_students(students_df):
    """
    Creates a list of Student objects from a 2-column dataframe of student names and their preferred flex time.
    """
    students = []

    for _, row in students_df.iterrows():
        student = Student(row['name'], row['flex_time'], row['location'])
        students.append(student)
    
    return students

def create_physicians(physicians_df):
    """
    Creates a list of Physician objects from a dataframe of physicians with the associated speciality and their availability.
    """
    physicians = []

    for _, row in physicians_df.iterrows():
        physician = Physician(
            row['name'],
            row['speciality'],
            row['location'],
            row['monAM'],
            row['monPM'],
            row['tueAM'],
            row['tuePM'],
            row['wedAM'],
            row['wedPM'],
            row['thuAM'],
            row['thuPM']
        )
        physicians.append(physician)

    return physicians

def find_time(student, physician):
    for time_slot in student.assignment:
        if (student.assignment[time_slot] == None) and (physician.availability[time_slot]):
            return time_slot
    return None

def generate_student_schedule(students):
    """
    Generates a human-readable dataframe where each row represents a student. The assignment on each session is given in the column with the physicians name and speciality
    """
    # Create an empty DataFrame to store the schedule
    schedule_df = pd.DataFrame(columns=["Student", "monAM", "monPM", "tueAM", "tuePM", "wedAM", "wedPM", "thuAM", "thuPM"])

    # Iterate through each student
    for student in students:
        schedule = {
            "Student": student.name,
            "monAM": "FLEX" if student.assignment["monAM"] == "FLEX" else "free time",
            "monPM": "FLEX" if student.assignment["monPM"] == "FLEX" else "free time",
            "tueAM": "FLEX" if student.assignment["tueAM"] == "FLEX" else "free time",
            "tuePM": "FLEX" if student.assignment["tuePM"] == "FLEX" else "free time",
            "wedAM": "FLEX" if student.assignment["wedAM"] == "FLEX" else "free time",
            "wedPM": "FLEX" if student.assignment["wedPM"] == "FLEX" else "free time",
            "thuAM": "FLEX" if student.assignment["thuAM"] == "FLEX" else "free time",
            "thuPM": "FLEX" if student.assignment["thuPM"] == "FLEX" else "free time"
        }

        # Iterate through the assignments to fill in the physician names
        for time_slot, physician in student.assignment.items():
            if physician != "FLEX" and physician != None:
                schedule[time_slot] = physician.name + " (" + physician.speciality + ", " + physician.location + ")"

        # Append the schedule for the current student to the DataFrame
        schedule_df.loc[len(schedule_df)] = schedule
        #schedule_df = schedule_df.append(schedule, ignore_index=True)

    return schedule_df

# %%
students_df = pd.read_csv("./input/students.csv")
physicians_df = pd.read_csv("./input/physicians.csv")

students = create_students(students_df)
physicians = create_physicians(physicians_df)

for student in students:
    for specialty in student.specialities_assigned:
        while student.specialities_assigned[specialty] > 0:
            for physician in physicians:
                if physician.speciality == specialty:
                    time_slot = find_time(student, physician)
                    if time_slot != None:
                        student.update_assignment(time_slot, physician)
                        physician.update_availability(time_slot)
                        student.specialities_assigned[specialty] -= 1
                        break

#for student in students:
#    print(student)
schedule_df = generate_student_schedule(students)
schedule_df
# Out:
#       Student                                              monAM  \
# 0    student1      Dobler, Kimberly (FM, Avon REJ Health Center)
# 1    student2                    Bohn , Timothy (IM, Avon (REJ))
# 2    student3  DePalma-Duersch, Jennifer (Peds, Avon Pointe F...
# 3    student4                                               FLEX
# 4    student5                                               FLEX
# 5    student6           Marsh, Lisa (FM, Avon REJ Health Center)
# 6    student7           Estrella, Karen (Peds, Avon Pointe FHC )
# 7    student8  Goettemoeller, NP, Michelle (FM, Avon REJ Heal...
# 8    student9                Ronan Factora, MD (Geriatrics, X10)
# 9   student10                 Gannon , Patricia (IM, Avon (REJ))
# 10  student11              Ardeshir Hashmi, MD (Geriatrics, X10)
# 11  student12                                          free time
# 12  student13     Chisholm, Jessica (FM, Avon REJ Health Center)
# 13  student14                                          free time
# 14  student15             Francy, Scott (Peds, Avon Pointe FHC )
# 15  student16           Cloud, Lisa (FM, Avon REJ Health Center)
# 16  student17           Hiba Khan, MD (Monday) (Geriatrics, X10)
#
#                                                 monPM  \
# 0       Dobler, Kimberly (FM, Avon REJ Health Center)
# 1   DePalma-Duersch, Jennifer (Peds, Avon Pointe F...
# 2                     Bohn , Timothy (IM, Avon (REJ))
# 3                 Ronan Factora, MD (Geriatrics, X10)
# 4            Marsh, Lisa (FM, Avon REJ Health Center)
# 5                                           free time
# 6               Ardeshir Hashmi, MD (Geriatrics, X10)
# 7                  Gannon , Patricia (IM, Avon (REJ))
# 8   Goettemoeller, NP, Michelle (FM, Avon REJ Heal...
# 9                                           free time
# 10                                          free time
# 11           Estrella, Karen (Peds, Avon Pointe FHC )
# 12                                               FLEX
# 13     Chisholm, Jessica (FM, Avon REJ Health Center)
# 14           Hiba Khan, MD (Monday) (Geriatrics, X10)
# 15                    Garcia, Ronald (IM, Avon (REJ))
# 16           Cloud, Lisa (FM, Avon REJ Health Center)
#
#                                                 tueAM  \
# 0                     Bohn , Timothy (IM, Avon (REJ))
# 1       Dobler, Kimberly (FM, Avon REJ Health Center)
# 2                                                FLEX
# 3   DePalma-Duersch, Jennifer (Peds, Avon Pointe F...
# 4            Marsh, Lisa (FM, Avon REJ Health Center)
# 5                 Ronan Factora, MD (Geriatrics, X10)
# 6                                           free time
# 7            Estrella, Karen (Peds, Avon Pointe FHC )
# 8                                           free time
# 9   Goettemoeller, NP, Michelle (FM, Avon REJ Heal...
# 10                 Gannon , Patricia (IM, Avon (REJ))
# 11                                               FLEX
# 12     Chisholm, Jessica (FM, Avon REJ Health Center)
# 13              Ardeshir Hashmi, MD (Geriatrics, X10)
# 14                                          free time
# 15                                          free time
# 16             Francy, Scott (Peds, Avon Pointe FHC )
#
#                                                 tuePM  \
# 0   DePalma-Duersch, Jennifer (Peds, Avon Pointe F...
# 1       Dobler, Kimberly (FM, Avon REJ Health Center)
# 2                 Ronan Factora, MD (Geriatrics, X10)
# 3                     Bohn , Timothy (IM, Avon (REJ))
# 4                                           free time
# 5            Marsh, Lisa (FM, Avon REJ Health Center)
# 6                                           free time
# 7               Ardeshir Hashmi, MD (Geriatrics, X10)
# 8            Estrella, Karen (Peds, Avon Pointe FHC )
# 9                                                FLEX
# 10  Goettemoeller, NP, Michelle (FM, Avon REJ Heal...
# 11                 Gannon , Patricia (IM, Avon (REJ))
# 12                                          free time
# 13     Chisholm, Jessica (FM, Avon REJ Health Center)
# 14                                          free time
# 15                                          free time
# 16                                               FLEX
#
#                                                 wedAM  \
# 0                 Ronan Factora, MD (Geriatrics, X10)
# 1                                           free time
# 2       Dobler, Kimberly (FM, Avon REJ Health Center)
# 3                                           free time
# 4                     Bohn , Timothy (IM, Avon (REJ))
# 5   DePalma-Duersch, Jennifer (Peds, Avon Pointe F...
# 6            Marsh, Lisa (FM, Avon REJ Health Center)
# 7                                           free time
# 8                                                FLEX
# 9   Goettemoeller, NP, Michelle (FM, Avon REJ Heal...
# 10                                               FLEX
# 11              Ardeshir Hashmi, MD (Geriatrics, X10)
# 12                 Gannon , Patricia (IM, Avon (REJ))
# 13                                               FLEX
# 14     Chisholm, Jessica (FM, Avon REJ Health Center)
# 15           Estrella, Karen (Peds, Avon Pointe FHC )
# 16                                          free time
#
#                                                 wedPM  \
# 0                                           free time
# 1                 Ronan Factora, MD (Geriatrics, X10)
# 2       Dobler, Kimberly (FM, Avon REJ Health Center)
# 3                                           free time
# 4   DePalma-Duersch, Jennifer (Peds, Avon Pointe F...
# 5                     Bohn , Timothy (IM, Avon (REJ))
# 6            Marsh, Lisa (FM, Avon REJ Health Center)
# 7                                           free time
# 8                                           free time
# 9                                           free time
# 10  Goettemoeller, NP, Michelle (FM, Avon REJ Heal...
# 11                                          free time
# 12           Estrella, Karen (Peds, Avon Pointe FHC )
# 13                 Gannon , Patricia (IM, Avon (REJ))
# 14     Chisholm, Jessica (FM, Avon REJ Health Center)
# 15              Ardeshir Hashmi, MD (Geriatrics, X10)
# 16                                          free time
#
#                                                 thuAM  \
# 0                                           free time
# 1                                           free time
# 2                                           free time
# 3       Dobler, Kimberly (FM, Avon REJ Health Center)
# 4                 Ronan Factora, MD (Geriatrics, X10)
# 5                                           free time
# 6                     Bohn , Timothy (IM, Avon (REJ))
# 7                                                FLEX
# 8            Marsh, Lisa (FM, Avon REJ Health Center)
# 9   DePalma-Duersch, Jennifer (Peds, Avon Pointe F...
# 10                                          free time
# 11  Goettemoeller, NP, Michelle (FM, Avon REJ Heal...
# 12              Ardeshir Hashmi, MD (Geriatrics, X10)
# 13           Estrella, Karen (Peds, Avon Pointe FHC )
# 14                 Gannon , Patricia (IM, Avon (REJ))
# 15                                               FLEX
# 16     Chisholm, Jessica (FM, Avon REJ Health Center)
#
#                                                 thuPM
# 0                                                FLEX
# 1                                                FLEX
# 2                                           free time
# 3       Dobler, Kimberly (FM, Avon REJ Health Center)
# 4                                           free time
# 5                                                FLEX
# 6                                                FLEX
# 7            Marsh, Lisa (FM, Avon REJ Health Center)
# 8                     Bohn , Timothy (IM, Avon (REJ))
# 9                 Ronan Factora, MD (Geriatrics, X10)
# 10  DePalma-Duersch, Jennifer (Peds, Avon Pointe F...
# 11  Goettemoeller, NP, Michelle (FM, Avon REJ Heal...
# 12                                          free time
# 13                                          free time
# 14                                               FLEX
# 15     Chisholm, Jessica (FM, Avon REJ Health Center)
# 16                 Gannon , Patricia (IM, Avon (REJ))
